# %% [markdown]
# # Importing experiment data

# %%
# %matplotlib inline
# %run ../../lib/pyFitIt.py

exp = LoadExperiment('.', fitType='1', expType='initial')
# Out:
# /opt/anaconda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# <style>
#     .container { width:100% !important; }
#     .output_area {display:inline-block !important; }
#     .cell > .output_wrapper > .output {margin-left: 14ex;}
#     .out_prompt_overlay.prompt {min-width: 14ex;}
#     .fitBySlidersOutput {flex-direction:row !important; }
#     /*.fitBySlidersOutput .p-Widget.jupyter-widgets-output-area.output_wrapper {display:none} - прячет ошибки*/
#     .fitBySlidersOutput div.output_subarea {max-width: inherit}
#     .fitBySlidersExafsOutput {flex-direction:row !important; }
#     /*.fitBySlidersExafsOutput .p-Widget.jupyter-widgets-output-area.output_wrapper {display:none} - прячет ошибки*/
# ...

# %% [markdown]
# # Importing XANES calculated for support points

# %%
sample = readSample('fit1')

# %% [markdown]
# # Construct the iverse estimator

# %%
convolutionParams = {'Gamma_hole':1, 'Ecent':50, 'Elarg':50, 'Efermi':-9, 'Gamma_max':15, 'shift':8976, 'norm':None}
inverseEstimator = constructInverseEstimator('RBF', exp, convolutionParams, CVcount=2, folderToSaveCVresult='inverseEstimator_CVresult')

# %% [markdown]
# # Compare different machine learning methods

# %%
inverseEstimator.compareDifferentMethods(sample, folderToSaveResult = 'result')
# Out:
# <img src="data:image/png;base64,..." width="1066">
# Ridge relative to constant prediction error =  0.23
#
# Ridge Quadric relative to constant prediction error = 0.0916
#
# Extra Trees relative to constant prediction error = 0.0555
#
# RBF relative to constant prediction error = 0.028
#
# LightGBM relative to constant prediction error = 0.0933

# %% [markdown]
# # Train the estimator

# %%
inverseEstimator.fit(sample)
# Out:
# Inverse method relative to constant prediction error = 0.0587
# L2 mean error =  0.21

# %% [markdown]
# # Start automatic fitting

# %%
inverseMethod.findGlobalL2NormMinimum(2, inverseEstimator, folderToSaveResult = 'inverseMethodResults')
# Out:
# fmin = 0.6097161447383753 d1=0.40527  d2=0.11186  d3=0.095437  d4=0.13861  d5=0.27964
# fmin = 0.47423588982229925 d1=0.91298  d2=-0.10881  d3=-0.19715  d4=-0.11976  d5=-0.070803
# L2 norm = 0.47 d1=0.91 d2=-0.11 d3=-0.2 d4=-0.12 d5=-0.071
# L2 norm = 0.61 d1=0.41 d2=0.11 d3=0.095 d4=0.14 d5=0.28
